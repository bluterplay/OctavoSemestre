# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# ## Normal bivariada teórica $\mathbf{\mu}=\begin{bmatrix} 0\\0\end{bmatrix}, \Sigma = \begin{bmatrix} 1& \frac{1}{2}\\\frac{1}{2}&1\\\end{bmatrix}$

# %%
T = 1000
normal_multivariada = np.random.multivariate_normal([0,0],[[1,0.5],[0.5,1]],T)

# %%
plt.scatter(normal_multivariada[:,0],normal_multivariada[:,1])

# %% [markdown]
# ## Simulación usando distribuciones condicionales
# $p(x\vert y) = \mathcal{N}(\rho y,1-\rho^2)\\
# p(y\vert x) = \mathcal{N}(\rho x,1-\rho^2)\\
# $

# %%
X = [1]
Y = [-1]

# %%
for _ in range(T):
    X.append(np.random.normal(Y[-1]/2, np.sqrt(3/4)))
    Y.append(np.random.normal(X[-1]/2, np.sqrt(3/4)))

# %%
plt.scatter(X, Y)

# %%
sns.distplot(normal_multivariada[:,0])
sns.distplot(X)
# Out:
# /tmp/ipykernel_6431/1660813102.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(normal_multivariada[:,0])
# /tmp/ipykernel_6431/1660813102.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X)
# <Axes: ylabel='Density'>

# %%
sns.distplot(normal_multivariada[:,1])
sns.distplot(Y)
# Out:
# /tmp/ipykernel_6431/261121353.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(normal_multivariada[:,1])
# /tmp/ipykernel_6431/261121353.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Y)
# <Axes: ylabel='Density'>

# %%
fig = plt.figure(figsize=(5,5),dpi=200)
ax = fig.add_subplot(111)
ax.scatter(X, Y,c='blue');
ax.plot(X, Y,c='red', marker='+',alpha=.12)


plt.scatter(normal_multivariada[:,0],normal_multivariada[:,1])

# %%
plt.plot(X)

# %%
plt.plot(Y)
