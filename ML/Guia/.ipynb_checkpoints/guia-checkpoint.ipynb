# %% [markdown]
# ## Modulos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import  StandardScaler, MinMaxScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.decomposition import KernelPCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Funciones relevantes

# %%
def grafica(x,y,clf,titulo):
    X1,X2= np.meshgrid(np.arange(start=x[:,0].min()-1, stop= x[:,0].max()+1,step= .01),
                   np.arange(start=x[:,1].min()-1, stop= x[:,1].max()+1,step= .01))
    plt.contourf(X1,X2,clf.predict(np.array([X1.ravel(),X2.ravel()]).T).reshape(X1.shape),
                alpha=.75,cmap=ListedColormap(('red','green','blue')))
    plt.xlim(X1.min(),X1.max())
    plt.ylim(X2.min(),X2.max())

    for i,j in enumerate(np.unique(y)):
        plt.scatter(x[y==j,0],x[y==j,1],
                    c= ListedColormap(('red','green','blue'))(i),label=j)

    plt.title(titulo)
    plt.show()

# %%
def graficaBinaria(x,y,clf,titulo):
    X1,X2= np.meshgrid(np.arange(start=x[:,0].min()-1, stop= x[:,0].max()+1,step= .01),
                   np.arange(start=x[:,1].min()-1, stop= x[:,1].max()+1,step= .01))
    plt.contourf(X1,X2,clf.predict(np.array([X1.ravel(),X2.ravel()]).T).reshape(X1.shape),
                alpha=.75,cmap=ListedColormap(('red','blue')))
    plt.xlim(X1.min(),X1.max())
    plt.ylim(X2.min(),X2.max())

    for i,j in enumerate(np.unique(y)):
        plt.scatter(x[y==j,0],x[y==j,1],
                    c= ListedColormap(('red','blue'))(i),label=j)

    plt.title(titulo)
    plt.show()

# %% [markdown]
# ## Cargar datos

# %%
data1= pd.read_csv("ConjuntoDeDatos1.csv")
data2= pd.read_csv("ConjuntoDeDatos2.csv")

# %%
data1.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline  Customer_Segment
# 0   3.92     1065                 1
# ...

# %%
data2["Gender"]=data2["Gender"].apply(lambda x: 1 if x=='Male' else 0)

# %%
data2.head()
# Out:
#     User ID  Gender   Age  EstimatedSalary  Purchased
# 0  15624510       1  19.0          19000.0          0
# 1  15810944       1  35.0          20000.0          0
# 2  15668575       0  26.0          43000.0          0
# 3  15603246       0  27.0          57000.0          0
# 4  15804002       1  19.0          76000.0          0

# %% [markdown]
# ## Preproceasamiento de los datos

# %%
X= data1.iloc[:,0:13].values
y= data1.iloc[:,13].values
X2= data2.iloc[:,1:3].values
y2= data2.iloc[:,4].values

# %% [markdown]
# ### Dividir datos

# %%
x_train,x_test,y_train,y_test= train_test_split(X,y, test_size=.25, random_state=0)
x2_train,x2_test,y2_train,y2_test= train_test_split(X2,y2, test_size=.25, random_state=0)

# %% [markdown]
# ### Escalamiento de los datos

# %%
sx= StandardScaler()
x_train= sx.fit_transform(x_train)
x_test= sx.fit_transform(x_test)
sx2= StandardScaler()
x2_train= sx2.fit_transform(x2_train)
x2_test= sx2.fit_transform(x2_test)

# %%
dc_acurracy={}

# %% [markdown]
# ## PCA

# %%
pca= PCA(n_components=2)
x_train= pca.fit_transform(x_train)
x_test= pca.transform(x_test)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.37281068, 0.18739996])

# %% [markdown]
# ### Arbol de clasificacion

# %%
tree = DecisionTreeClassifier(random_state=0, min_samples_leaf=3)
tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(min_samples_leaf=3, random_state=0)

# %% [markdown]
# #### Matriz de confusión

# %%
y_tree=tree.predict(x_test)
cm= confusion_matrix(y_test,y_tree)

# %%
dc_acurracy["arbol PCA"]= accuracy_score(y_test, y_tree)

# %%
cm
# Out:
# array([[16,  0,  0],
#        [ 1, 18,  2],
#        [ 0,  0,  8]])

# %% [markdown]
# #### Visualización

# %%
grafica(x_train,y_train,tree, "Arbol de decisión PCA conjunto de entrenamiento")
# Out:
# /tmp/ipykernel_4405/3153371840.py:10: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x[y==j,0],x[y==j,1],

# %%
grafica(x_train,y_train,tree, "Arbol de decisión PCA conjunto de prueba")
# Out:
# /tmp/ipykernel_4405/3153371840.py:10: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x[y==j,0],x[y==j,1],

# %% [markdown]
# ## LDA

# %% [markdown]
# ### Arbol de regresión

# %%
lda = LDA(n_components=2)
x_train=lda.fit_transform(x_train, y_train)
x_test = lda.transform(x_test)

# %%
ldaTree = DecisionTreeRegressor()
ldaTree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# #### Confusión

# %%
y_ldaTree = ldaTree.predict(x_test)
cm = confusion_matrix(y_test,y_ldaTree)

# %%
dc_acurracy["arbol LDA"]= accuracy_score(y_test, y_ldaTree)

# %%
cm
# Out:
# array([[16,  0,  0],
#        [ 1, 17,  3],
#        [ 0,  0,  8]])

# %% [markdown]
# #### Visualizacion

# %%
grafica(x_train,y_train,ldaTree, "Arbol de regresion LDA conjunto de entrenamiento")
# Out:
# /tmp/ipykernel_4405/3153371840.py:10: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x[y==j,0],x[y==j,1],

# %%
grafica(x_test,y_test,ldaTree, "Arbol de regresión conjunto LDA de prueba")
# Out:
# /tmp/ipykernel_4405/3153371840.py:10: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x[y==j,0],x[y==j,1],

# %% [markdown]
# ### KNN

# %%
knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski',p=2)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# #### Matriz de confusion

# %%
y_knn=knn.predict(x_test)
cm= confusion_matrix(y_test,y_knn)

# %%
dc_acurracy["knn LDA"]= accuracy_score(y_test, y_knn)

# %%
cm
# Out:
# array([[16,  0,  0],
#        [ 1, 19,  1],
#        [ 0,  0,  8]])

# %% [markdown]
# #### Visualizaión

# %%
grafica(x_train,y_train,knn, "KNN  LDA conjunto de entrenamiento")
# Out:
# /tmp/ipykernel_4405/3153371840.py:10: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x[y==j,0],x[y==j,1],

# %%
grafica(x_test,y_test,knn, "KNN LDA conjunto de prueba")
# Out:
# /tmp/ipykernel_4405/3153371840.py:10: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x[y==j,0],x[y==j,1],

# %% [markdown]
# ## Comparativa

# %%
dc_acurracy
# Out:
# {'arbol PCA': 0.9333333333333333,
#  'arbol LDA': 0.9111111111111111,
#  'knn LDA': 0.9555555555555556}

# %% [markdown]
# ## Kernel PCA

# %%
transformer = KernelPCA(n_components=2, kernel='linear')
x2_train= transformer.fit_transform(x2_train)
x2_test= transformer.transform(x2_test)

# %% [markdown]
# ### Regresion Logistica

# %%
regLog= LogisticRegression(random_state=0)
regLog.fit(x2_train, y2_train)
# Out:
# LogisticRegression(random_state=0)

# %% [markdown]
# #### Matriz de confusion

# %%
y_log= regLog.predict(x2_test)
cm=confusion_matrix(y2_test,y_log)

# %%
cm
# Out:
# array([[63,  5],
#        [ 6, 26]])

# %% [markdown]
# #### Visualizacion

# %%
graficaBinaria(x2_train,y2_train, regLog, 'Regresión logistica KERNEL PCA datos de entrenamiento')
# Out:
# /tmp/ipykernel_4405/1797644939.py:10: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x[y==j,0],x[y==j,1],

# %%
graficaBinaria(x2_test,y2_test, regLog, 'Regresión logistica KERNEL PCA datos de prueba')
# Out:
# /tmp/ipykernel_4405/1797644939.py:10: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x[y==j,0],x[y==j,1],

# %% [markdown]
# ### Arboles de clasificación

# %%
tree2 = DecisionTreeClassifier(random_state=0, min_samples_leaf=3)
tree2.fit(x2_train,y2_train)
# Out:
# DecisionTreeClassifier(min_samples_leaf=3, random_state=0)

# %% [markdown]
# #### Matriz de confusion

# %%
y_tree2= tree2.predict(x2_test)
cm=confusion_matrix(y2_test,y_tree2)

# %%
cm
# Out:
# array([[61,  7],
#        [ 7, 25]])

# %% [markdown]
# #### Visualizacion

# %%
graficaBinaria(x2_train,y2_train, tree2, 'Arbol de clasificacion KERNEL PCA datos de entrenamiento')
# Out:
# /tmp/ipykernel_4405/1797644939.py:10: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x[y==j,0],x[y==j,1],

# %%
graficaBinaria(x2_test,y2_test, tree2, 'Arbol de clasificacion KERNEL PCA datos de prueba')
# Out:
# /tmp/ipykernel_4405/1797644939.py:10: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x[y==j,0],x[y==j,1],
